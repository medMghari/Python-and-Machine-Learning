# %%
# Out:
#                                                  Event  \
# 0                     WQU DS Module Introductory Video
# 1                  1.1.1 Basic Programming & Variables
# 2                                      1.1.2 Functions
# 3                1.1.3 Logic & Conditional Expressions
# 4                                      1.1.4 Iteration
# 5                         1.2.1 Data Structures (list)
# 6                        1.2.2 Data Structures (tuple)
# 7                          1.2.3 Data Structures (set)
# 8                         1.2.4 Data Structures (dict)
# 9           1.2.5 Data Structures (collections module)
# 10                                       Office Hour 1
# 11                                       Office Hour 2
# 12                                       Office Hour 3
# 13                                       Office Hour 4
# 14            2.1.1 Algorithms and Complexity Analysis
# 15                 2.1.2 Computational/Time Complexity
# ...
